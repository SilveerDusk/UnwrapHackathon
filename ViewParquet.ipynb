# %%
import pandas as pd

# %%
users = pd.read_parquet('users.parquet', engine="fastparquet")

# %%
users
# Out:
#         age_days  total_posts  total_comments  comment_to_post_ratio  \
# 0     545.996038           32              50               1.562500
# 1     431.487577            1              50              50.000000
# 2       7.148326            1               5               5.000000
# 3     492.443062           11              50               4.545455
# 4     146.767588            7              50               7.142857
# ..           ...          ...             ...                    ...
# 692  1464.856132            4              50              12.500000
# 693   407.400892           50              50               1.000000
# 694  2966.939330           50              50               1.000000
# 695   295.558877            2              50              25.000000
# 696  2586.325646           50              50               1.000000
#
#      subreddit_diversity  activity_spike  post_to_karma_ratio  posts_per_day  \
# 0                     23               0             0.019560       0.150184
# 1                     10               1             0.007463       0.115878
# 2                      3               0             0.045455       0.839357
# 3                     22               1             0.017886       0.123872
# 4                     11               1             0.042424       0.388369
# ..                   ...             ...                  ...            ...
# 692                    7               0             0.000964       0.036864
# 693                   20               1             0.009152       0.245458
# 694                   31               1             0.000984       0.033705
# 695                    9               1             0.011494       0.175938
# 696                   45               1             0.004975       0.038665
#
#                  username
# 0     SacredRealmOfficial
# 1     Interesting_Run_626
# 2       Odd-Bullfrog-5433
# 3    RevolutionaryFly5970
# 4      PeterPipersPicklez
# ..                    ...
# 692           adrenacapra
# 693       FromtheAshes505
# 694        samirbinballin
# 695  Acceptable_Delay_148
# 696                rawaka
#
# [697 rows x 9 columns]

# %%
user_scores = pd.read_parquet('user_scores.parquet', engine="fastparquet")

# %%
len(user_scores[user_scores['score'] > 0.8]) / len(user_scores)
# Out:
# 0.24275862068965517
